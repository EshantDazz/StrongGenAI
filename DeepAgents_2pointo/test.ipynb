# %% [markdown]
# - Planning(ToDo)
# - Subagents
# - FileSystem(Memory)
# - Prompt Caching
# - System prompt
# - sanboxes(to run scripts)
# - memory
# - skills
# - summarization

# %% [markdown]
# ![DeepAgent vs Claude SDK](assets/DEepagent%20vs%20claude%20sdk.png)

# %% [markdown]
# ## Backend
#
# - ls, write file, read file, edit file, grep, glob
# - read also supports images ,gif and webp
