# %%
from dotenv import load_dotenv 

_=load_dotenv()

# %% [markdown]
# ## PII Detection

# %%
from guardrails.hub import DetectPII
from guardrails import Guard, OnFailAction
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from guardrails.hub import DetectPII
#       2 from guardrails import Guard, OnFailAction
#
# ImportError: cannot import name 'DetectPII' from 'guardrails.hub' (/Users/eshantdas/Desktop/SelfStudy/PersonalTest/KrishNaikUdemyLLMSecurity_gateways/.venv/lib/python3.13/site-packages/guardrails/hub/__init__.py)
