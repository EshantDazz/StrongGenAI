# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Verify the installation — PyRIT 0.14+ compatible
import importlib.metadata
print(f"PyRIT version: {importlib.metadata.version('pyrit')}")

from pyrit.prompt_target import OpenAIChatTarget
from pyrit.prompt_normalizer import PromptNormalizer
from pyrit.memory import SQLiteMemory, CentralMemory
from pyrit.models import Message, MessagePiece
from pyrit.score import SelfAskTrueFalseScorer, TrueFalseQuestion
from pyrit.prompt_converter import Base64Converter

print("All core modules imported successfully!")
# Out:
# PyRIT version: 1.0.1
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 10
#       6 from pyrit.prompt_normalizer import PromptNormalizer
#       7 from pyrit.memory import SQLiteMemory, CentralMemory
#       8 from pyrit.models import Message, MessagePiece
#       9 from pyrit.score import SelfAskTrueFalseScorer, TrueFalseQuestion
# ---> 10 from pyrit.prompt_converter import Base64Converter
#      11
#      12 print("All core modules imported successfully!")
#
# ModuleNotFoundError: No module named 'pyrit.prompt_converter'
