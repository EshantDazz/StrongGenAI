# %% [markdown]
# ## Test Case
# -  Input
# - Expected Output
# - Actual Output

# %% [markdown]
# ## Custom Metrics(Natural Language Criteria)
# - Metric Name: Correctness
# - CHoose how to evaluate <br>
# Ceritera (COT) LLM will make its own evaluation steps here <br> or Evaluation steps(Define multiple steps on which it will evaluate)
#
# - We can also give evaluation parameters (for example which values from actual outputs are important and all)
#
# ### Advanced Customizations
# - Rubrics: Define Score ranges (0-10)<br>
# Example 0-2 Poor, 2-4 Fair, 4-6 Good ........<br>
#
# - Strict Mode
# strict_mode=True -> Binary pass /fail
# 1= perfect , 0 otherwise
#
# - CustomTemplates
# Provide evaluation_temp;ate to override default prompts. Useful for smaller models to enforce<br>
# Json-constrained outputs

# %% [markdown]
# ### Run GEval

# %% [markdown]
# ## PRocess
# - Step Generation
# - Prompt Createion based on the steps for the LLM as JUdge
# - Scoring is done (1 to 5) ( we also get probability of getting score 1 ,2 ,3.. which is called the logprob)
# - We normalise the score to 0 to 1<br>
# It is done using weighted summation of the probabilities of the LLM's output tokens
