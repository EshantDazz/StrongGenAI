# %% [markdown]
# ## Type of Nodes
#
# - `Task`: Actual Task happens over here for example extract data or process before evaluation
# - `Binary Judgement`: Strict Yes/ No check
# - `Non Binary Judgement`: Some scoring based judgement
# - `Verdict`: Leaf nodes it is the last node and it will create score based on judgement results
