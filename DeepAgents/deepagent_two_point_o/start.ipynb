# %%
from langchain_openai import ChatOpenAI

# %% [markdown]
# ## DeepAgent has 4 things
# - System Prompt
# - SubAgents (IT will complete the Todo List)
# - FileSystem (Persistent Memory)
# - PlannerTool (ToDO list)
